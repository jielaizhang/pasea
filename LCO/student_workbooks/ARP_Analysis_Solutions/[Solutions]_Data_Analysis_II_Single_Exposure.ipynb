# %% [markdown]
# # Processing A Single Exposure Image
#
# In this tutorial, you will learn how to perform photometry on a single image of your target star.
#
# Before doing this tutorial, you should have watched the _Introduction to Photometry_ video lecture linked in Slack. In this tutorial, you will
# 1. Review the basics on displaying data sets as `matplotlib` figures
# 2. Read in a fits image from your requested dataset and display it in Python
# 3. Calculate a value for the background for the whole image and subtract it
# 4. Pick out your target star and reference stars
#
# ==============================================
#
# We will then take all of these steps and put them together to:
# 5. Perform aperture photometry of your target
# 6. Create a cutout image around the target star
#
# You will be using many skills you learned in the PASEA Alumni Programming Python Workshops. Skills include reading in fits files, plotting and functional programming.
#
# This notebook requires installing the following Python modules. This should be set up already on the google co-lab platform but if you choose to run this notebook offline, you will require the following modules:
# * `astropy`
# * `imageio`

# %% [markdown]
# Just like before, let's start by loading in some important packages and modules:

# %%
# !pip install photutils

# Import statements

import warnings
warnings.filterwarnings('ignore')

import glob
import numpy as np

from photutils import Background2D, SExtractorBackground
from photutils import DAOStarFinder
from photutils import CircularAperture,aperture_photometry
from photutils.utils import calc_total_error

import astropy.wcs as wcs
from astropy.io import fits
from astropy.stats import sigma_clipped_stats, SigmaClip
from astropy.nddata.utils import Cutout2D
from astropy import units as u

import matplotlib.pyplot as plt
from astropy.visualization import ZScaleInterval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting photutils
#   Downloading photutils-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (826 kB)
#      |████████████████████████████████| 826 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from photutils) (1.21.6)
# Requirement already satisfied: astropy>=4.0 in /usr/local/lib/python3.7/dist-packages (from photutils) (4.3.1)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->photutils) (2.0.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from astropy>=4.0->photutils) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0->photutils) (3.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->astropy>=4.0->photutils) (4.1.1)
# Installing collected packages: photutils
# Successfully installed photutils-1.3.0

# %% [markdown]
# # 1. Tutorial on plotting images
#
# An image is a 2D array of numbers. You can display a 2D array of numbers as an image using `matplotlib.pyplot`'s `imshow`.
#
# The example below has pixel values mostly around 1-3, but one pixel value (lower left) is 1000. When you display it, the 1000 pixel will be displayed as white and because the rest of the pixels are so close together in value, they will all appear black. This is because the range between 1 and 1000 is evenly assigned colours black to white in an even gradient.

# %%
simple_image = [[1.,2.,1.3],
                [1.9,2.3,1.8],
                [1000,2.1,1.4]]
plt.imshow(simple_image, cmap='gray')
# To see what color represents what value, add a colorbar: 
plt.colorbar()

# %% [markdown]
# What if we want to see the variation in pixel value of the pixels with values 1-3? We can ask imshow to plot all pixels brighter than 3 as white and all pixels fainter than 1 as black. This way, only the pixel values between 1 and 3 will need to be assigned colours black to white with an even gradient.
#
# `plt.colorbar` adds the colorbar on the right hand side.
#
# Notice in the image shown below, the colorbar now only shows colors for numbers between 1 and 3.
# Any value smaller than one will be black, any value larger than 3 will be white.
# E.g. Notice below the top left pixel value is 1, and it is black and the bottom left pixel value is 1000 and it is white.

# %%
simple_image = [[1.,  2., 1.3],
                [1.9, 2.3,1.8],
                [1000,2.1,1.4]]

plt.imshow(simple_image,vmin=1, vmax=3, cmap='gray')
plt.colorbar()

# %% [markdown]
# ## Exercises / Questions
#
# Try plotting the below image and setting your own vmax and vmin so that you see the following displayed for the simple_image defined below.
# ![example.png](data:image/png;base64,...)
#
# Also try plotting the image with a different cmap, which defines what the color to display the image.

# %%
# You can do your exercise in this cell, as well as make extra cells. 

simple_image = [[1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 976, 955, 1.9, 2.6, 2.5, 1.7 ],
                [1., 999, 985, 3.1, 0.9, 2.5, 1.7],
                [1., 3, 1.5, 3.1, 0.9, 1.8, 1.7],
                [1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 3.1, 1., 1.9, 12.4, 12.9, 1.7],
                [1., 2., 1.5, 3.1, 13., 12.3, 0.9],
                [5., 3.1, 1., 1.9, 2.6, 2.5, 1.7]
               ]

# Exercise: Add your code here such that you display your image so it looks like the example above

# %%
# You can do your exercise in this cell, as well as make extra cells. 

simple_image = [[1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 976, 955, 1.9, 2.6, 2.5, 1.7 ],
                [1., 999, 985, 3.1, 0.9, 2.5, 1.7],
                [1., 3, 1.5, 3.1, 0.9, 1.8, 1.7],
                [1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 3.1, 1., 1.9, 12.4, 12.9, 1.7],
                [1., 2., 1.5, 3.1, 13., 12.3, 0.9],
                [5., 3.1, 1., 1.9, 2.6, 2.5, 1.7]
               ]

# Exercise: Add your code here such that it displays your image with a different color map. 
# Note you can find out more about matplotlib color maps here: https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# There is a function that helps you set reasonable vmin and vmax values for any input image. It's called a zscale.
#
# The zscale algorithm is designed to display the image values near the _median image value_ without the time consuming process of computing a full image histogram. This is particularly useful for astronomical images which generally have a very peaked histogram corresponding to the background sky in direct imaging or the continuum in a two dimensional spectrum.
#
# Here is an example of how to use it.

# %%
simple_image = [[1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 976, 955, 1.9, 2.6, 2.5, 1.7 ],
                [1., 999, 985, 3.1, 0.9, 2.5, 1.7],
                [1., 3, 1.5, 3.1, 0.9, 1.8, 1.7],
                [1., 2., 1.5, 3.1, 0.9, 2.5, 1.7],
                [5., 3.1, 1., 1.9, 12.4, 12.9, 1.7],
                [1., 2., 1.5, 3.1, 13., 12.3, 0.9],
                [5., 3.1, 1., 1.9, 2.6, 2.5, 1.7]
               ]

interval = ZScaleInterval()
vmin     = interval.get_limits(simple_image)[0]
vmax     = interval.get_limits(simple_image)[1]
print('vmin: ',vmin)
print('vmax: ',vmax)

# Exercise: Use this automatically determined vmin and vmax to display your image.
# Out:
# vmin:  0.9
# vmax:  8.613069828722004

# %% [markdown]
# # 2. Read in a fits image from dataset and display it in Python
# First let's mount our GDrive:

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Now that we've connected our Colab notebook to GDrive, we can set up some parameters that contain both the path to our data and the filename of one of the exposures we downloaded in the previous notebook.
#
# Check out your GDrive directory and choose one of the V-filter files you downloaded and copy the filename.
#
# This can be done by either accessing your GDrive 📁LCO via the Drive browser or via the directory tree accessible in the sidebar to the left.
#
# Note: You can always find the path to your .fits file by clicking the three dots next to the file (highlighted by the <font color='magenta'>pink</font> box) and selecting "Copy Path to File":
#
# ![Screen Shot 2022-08-26 at 15.48.18.png](data:image/png;base64,...)

# %% [markdown]
# Next we're going to set the path to our mounted LCO directory and select one of the data files we downloaded to Drive in the "Get Data" notebook.

# %%
mypath = './drive/MyDrive/LCO/'
myfile = 'coj0m403-kb97-20191006-0057-e91.fits.fz'

# %% [markdown]
# Then open the fits file for the single image and display it. Notice in the `plt.imshow` line below, we set `origin='lower'`. This puts 0,0 in the bottom left instead of 0,0 in the top left as is the default (you can see in the above that 0,0 is in the top left.

# %%
# Plot the whole image with the reference star and target star marked to see if it all looks ok

# Read in the data and the fits file header information
sci_data, sci_header   = fits.getdata(mypath+myfile,header=True)

# Get the best vmin and vmax to visualize the image
# See why these two values were picked using ds9. 
interval = ZScaleInterval()
vmin     = interval.get_limits(sci_data)[0]
vmax     = interval.get_limits(sci_data)[1]
print('vmin: ',vmin)
print('vmax: ',vmax)

figure = plt.figure(figsize=(10,22))     # This sets the figure (image) size, and is larger than default.
im = plt.imshow(sci_data, vmin=vmin, vmax=vmax, origin='lower')
plt.colorbar(im,fraction=0.03, pad=0.03) # This sets the colorbar size and position.
# Out:
# vmin:  602.9613
# vmax:  952.1389014416832

# %% [markdown]
# # 3. Calculate the background for the whole image and subtract it.
#
# Even if no visible astronomical objects are present in given part of the sky, there always is some low luminosity present (known as the _sky background_) due mostly to light diffusion from the atmosphere. This includes the diffusion of both incoming light from nearby sources and of man-made Earth sources like cities. This sky background also changes over time, so it needs to be subtracted off any data images before they undergo photometry of the target. A background frame is first calculated and then subtracted from the actual observation result, leaving (in theory) only the incoming light from the astronomical object being observed.
#
# Here, we will estimate the background of every pixel in the image, then subtract it from the image to get a background subtracted image with which we can measure the brightness of stars. To estimate the background we will use a software called `Source Extractor`. You can learn more about this software [here](https://sextractor.readthedocs.io/en/latest/Introduction.html).

# %%
# Sigma clip bright obvious things to avoid biasing the background estimate
sigma_clip    = SigmaClip(sigma=3.) 

# Apply the SExtractor algorithm to our estimation
bkg_estimator = SExtractorBackground() 
bkg           = Background2D(   sci_data, (50, 50),
                                filter_size=(3, 3),
                                sigma_clip=sigma_clip,
                                bkg_estimator=bkg_estimator )

# Now let's subtract the background from the data
# The background that Source Extractor calculated is stored in the variable bkg.background. 
sci_bkg = sci_data - bkg.background

# %% [markdown]
# ## Exercise / Question
#
# Display the background image found above, i.e. bkg.background. You can use what you learned about displaying images in the "1. Tutorial on plotting images" above. Just like the fits image displayed above, put the origin of your image in the lower left.

# %%
interval = ZScaleInterval()
vmin = interval.get_limits(bkg.background)[0]
vmax = interval.get_limits(bkg.background)[1]
print('vmin: ',vmin)
print('vmax: ',vmax)

#figure = plt.figure(figsize=(12,24))
im = plt.imshow(bkg.background, vmin=vmin, vmax=vmax, origin='lower', cmap='gray')
plt.colorbar()
#plt.colorbar(im,fraction=0.03, pad=0.03)
# Out:
# vmin:  691.5015219789913
# vmax:  763.3085478024583

# %% [markdown]
# # Exercise / Question
#
# Play around a little with the `sigma` value set in SigmaClip in the `Sextractor` cell above. What do you think this parameter controls/determines?
#
# ❕Remember to set this `sigma` value back to 3.0 before continuing on.

# %% [markdown]
# ## Exercise / Question
# Show the background subtracted image and see what it looks like. Can you tell that it's been background subtracted? Does it look different to the original image?

# %%
# Show the background subtracted image

# %% [markdown]
# # 4. Pick out the target and reference stars
#
# As you learned in the _Introduction to Photometry_ tutorial, to do photometry, you need to determine a zeropoint that needs to be added to the uncalibrated magnitude of stars in your image to turn them into _calibrated_ magnitudes. Calibrated magnitudes are useful as they directly relate to physical flux units (where flux is measured in energy per second per collecting area).
#
# E.g.
# 1. You add up the pixel values in background subtracted image of the reference star, let this be counts_ccd_ref = 10,000
# 2. you turn this into uncalibrated magnitude, m_uncalibrated_ref = -2.5*log10(counts_ccd_ref) = -10
# 3. Since this is a reference star, others have measured the calibrated magnitude, let's say it is m_calibrated_ref = 17
# 4. then your zerpoint, zp = m_calibrated_ref - m_uncalibrated_ref = 17 - (-10) = 27.
# 5. You can now find the calibrated magnitude of any star that you count up the pixel values for.
# 6. Say counts_ccd_MYSTAR = 1000
# 7. m_uncalibrated_MYSTAR = -2.5*log10(counts_ccd_MYSTAR) = -7.5
# 8. m_calibrated_MYSTAR = m_uncalibrated_MYSTAR + zp = -7.5 + 27 = 19.5
#
# We will use a series of reference stars to calculate the zeropoint (we will find zeropoints for all of them and use the median as our zeropoint). The best quality reference stars are bright stars that are not saturated.
#
# A PASEA Instructor will have provided you with a `wget` command that will download a list of potential reference stars for your target. Please enter it below.

# %%
# !wget -O '/content/drive/MyDrive/LCO/TargetA_reflist.csv' https://www.dropbox.com/s/07eec7xga1ql60n/TargetA_reflist.csv?dl=0
# Out:
# --2022-09-13 07:33:42--  https://www.dropbox.com/s/07eec7xga1ql60n/TargetA_reflist.csv?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:601b:18::a27d:812
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/07eec7xga1ql60n/TargetA_reflist.csv [following]
# --2022-09-13 07:33:42--  https://www.dropbox.com/s/raw/07eec7xga1ql60n/TargetA_reflist.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com/cd/0/inline/Bs1pFSXfiV1RIyrROjfQlQnhDhZQ0xc8A55buDz1r6QzwAsRHxI89n8LreDBtEKp4e3I0hrHztx1TJoW0BHGlCxdgRwqzkEn9jQBU5s23b7ah6r9IM6mCjG3haBtlT5s0n0fbho0ctF64yxC-AnMZfUhCGeMsXrGkYTVC10Ni7sjNQ/file# [following]
# --2022-09-13 07:33:43--  https://ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com/cd/0/inline/Bs1pFSXfiV1RIyrROjfQlQnhDhZQ0xc8A55buDz1r6QzwAsRHxI89n8LreDBtEKp4e3I0hrHztx1TJoW0BHGlCxdgRwqzkEn9jQBU5s23b7ah6r9IM6mCjG3haBtlT5s0n0fbho0ctF64yxC-AnMZfUhCGeMsXrGkYTVC10Ni7sjNQ/file
# Resolving ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com (ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com (ucd771ee765a1a020b57cda439f5.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 919 [text/plain]
# Saving to: ‘/content/drive/MyDrive/LCO/TargetA_reflist.csv’
#
# /content/drive/MyDr 100%[===================>]     919  --.-KB/s    in 0s
#
# 2022-09-13 07:33:43 (47.0 MB/s) - ‘/content/drive/MyDrive/LCO/TargetA_reflist.csv’ saved [919/919]

# %% [markdown]
# Now we will be loading in the reference star lists using `pandas`. Recall that you learned about how to use `pandas` in the PASEA-ARP Python Workshop. Load in your reference star list.

# %%
import pandas as pd
refstar_df = pd.read_csv('/content/drive/MyDrive/LCO/TargetA_reflist.csv', comment="#")
pd.set_option('display.max_rows', None)
refstar_df
# Out:
#          radeg  raerr(")    decdeg  decerr(")  Johnson_V   Verr  Johnson_B  \
# 0   299.235864     0.362 -1.208262      0.147      8.634  0.014      9.939
# 1   299.164421     0.510 -1.098525      0.121     10.122  0.107     10.705
# 2   299.233458     0.501 -0.955927      0.085     10.364  0.086     11.794
# 3   299.076430     0.370 -0.945250      0.208     11.194  0.089     12.372
# 4   299.206894     0.375 -1.126769      0.140     11.438  0.099     12.119
# 5   299.199018     0.497 -1.089140      0.111     11.444  0.096     13.211
# 6   299.172559     0.539 -1.213148      0.245     12.156  0.089     12.724
# 7   299.347536     0.429 -1.231549      0.604     12.297  0.128     14.019
# 8   299.134648     0.142 -0.960250      0.084     12.332  0.091     13.644
# 9   299.216709     0.320 -1.017877      0.137     13.194  0.099     13.815
# 10  299.223853     0.279 -0.941202      0.237     13.790  0.080     14.580
# 11  298.986162     0.495 -0.784590      0.394     14.107  0.088     15.361
# 12  299.186903     0.315 -1.045935      0.287     15.158  0.117     16.316
#
#      Berr  R(deg)
# 0   0.127   0.194
# 1   0.048   0.080
# 2   0.044   0.081
# 3   0.039   0.133
# 4   0.056   0.108
# 5   0.054   0.069
# 6   0.024   0.192
# 7   0.050   0.265
# 8   0.042   0.080
# 9   0.058   0.031
# 10  0.054   0.089
# 11  0.030   0.310
# 12  0.077   0.025

# %% [markdown]
# Now let's load in the RA of Dec of the target.

# %%
# Target star RA and DEC. This is where you enter the RA and Dec coordinates of your target star. We want to try and find the magnitude of this star.
target_RA  = 299.18555
target_DEC = -1.0214

# %% [markdown]
# The next step will be to select between 5-8 reference stars from the list above. Enter their values in the lists below:

# %%
# Useful reference stars are ones which are bright, but not saturated, and stars which lie within the field of view. 

#-------------------------------------------------------------------
# TO DO: From the list above, choose 5-8 reference stars.
#-------------------------------------------------------------------
# Construct Python lists for the RA and Dec coordinate values for the stars you've selected from the list above. 
# The list mag_calibrated_ref should be defined by a Python list of the relevant magnitudes (make sure to check what filter was used to capture this frame!) for your chosen reference stars.
# This subset of stars was selected from the APASS DR20 catalog which can be accessed here: 
# https://www.aavso.org/apass-dr10-download

ref_ra             = refstar_df['radeg'].tolist()
ref_dec            = refstar_df['decdeg'].tolist()
mag_calibrated_ref = refstar_df['Johnson_V'].tolist()

# %% [markdown]
# ## Let's visualise where on the image our target and reference stars are located in this frame.
# To do this, we have to mark circles where the target and reference stars are. We have to know the x,y position in pixel coordinates for this image, and not just the RA and DEC. To get the x,y pixel coordinates, we use `AstroPy` and  the World Coordinate System information in the header of the fits image to convert RA/DEC to x,y pixels.

# %%
# Plot the whole image (background subtracted version) with the reference star and target star marked to see if it all looks ok

# Read in the data and the fits file header information
sci_data, sci_header   = fits.getdata(mypath+myfile,header=True)

# Get the World Coordinate System (WCS) from the fits header. 
w                            = wcs.WCS(sci_header)

# Convert RA and DEC to x,y pixel coordinate for ref and target stars using the WCS. 
xcoord_ref, ycoord_ref       = w.all_world2pix(ref_ra,ref_dec,1)
xcoord_target, ycoord_target = w.all_world2pix([target_RA],[target_DEC],1)

# Get the best vmin and vmax to visualize the image
interval = ZScaleInterval()
vmin     = interval.get_limits(sci_bkg)[0]
vmax     = interval.get_limits(sci_bkg)[1]

# Plot the figure
figure = plt.figure(figsize=(12,24))
plt.imshow(sci_bkg, vmin=vmin, vmax=vmax, origin='lower')

# Mark with a red circle the target stars. 
plt.scatter(xcoord_target,ycoord_target,marker='o',
            facecolors='none',s=150,linewidth=1,color='red')

# Mark with white circles the reference stars. 
plt.scatter(xcoord_ref,ycoord_ref,marker='o',
            facecolors='none',s=150,linewidth=1,color='white')

# %% [markdown]
# Reflect on what you see in the figure above. Are you satisfied with your reference star choices? Take this moment to make any modifications to your reference star lists now before proceeding to the next section.

# %% [markdown]
# # ====================================
# # 5. Put it all together: Do Aperture Photometry
#
# This is where the photometry actually happens!
#
# *Important Note: All the steps are listed here from start to end. While it will include some repeated steps, this represents the FULL data analysis procedure in it's entirety.

# %% [markdown]
# ## A useful function
# A function that outputs the uncalibrated magnitude of a source, and its error. The inputs to the function are the background subtracted science image "data", the fits header "hdr", the error image "error" that you get from determining the background and the RA (`ra`) and DEC (`dec`) of the object you want to measure photometry to.
#
# You will be using this function to do photometry, so load it in!

# %%
def do_phot_get_mag(data,hdr,err,ra,dec):

    # Get the WCS from the input header or "hdr"
    w         = wcs.WCS(hdr)
    
    # Calculate the x,y pixel coordinates given the RA and DEC input
    xcoords, ycoords = w.all_world2pix(ra,dec,1)
    # Get it in the required format
    positions = np.transpose((xcoords, ycoords))
    
    # Set the aperture inside which to add up the pixel values
    apertures = CircularAperture(positions, r=24.)
    # Perform the photometry given the image, the apertures and the error image. 
    phot      = aperture_photometry(data, apertures, error=err)

    # calculate the uncalibrated magnitude of the sources
    mag     = list(-2.5*np.log10(phot['aperture_sum']) )
    # calculate the error of the uncalibrated magnitudes
    mag_err = list((2.5/np.log(10))*(phot['aperture_sum_err']/phot['aperture_sum']))
    
    return mag,mag_err

# %% [markdown]
# ### a. Open the frame and read out the data, header and time of observation

# %%
# Read in file
sci_data, sci_header   = fits.getdata(mypath+myfile,header=True)

# The "header" of fits files contains a lot of information on the image.

# Grab the time of observation of this image.
mjd      = sci_header['MJD-OBS']
datetime = sci_header['DATE']

# print RA and DEC in header, which tells you where the telescope was pointing when this image was taken.
print('RA:',sci_header['RA'])
print('DEC:',sci_header['DEC'])
# Out:
# RA: 19:56:44.0891
# DEC: -01:01:20.114

# %%
# print the whole header to have a look
print('\nEntire header:')
sci_header
# Out:
# Entire header:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 3054
# NAXIS2  =                 2042
# PCOUNT  =                    0 / size of special data area
# GCOUNT  =                    1 / one data group (required keyword)
# XTENSION= 'BINTABLE'           / binary table extension
# DATADICV= 'LCOGT-DIC.FITS-0.11.0' / Version number of the data dictionary
# HDRVER  = 'LCOGT-HDR-1.4.0'    / Version number of the headers
# ORIGIN  = 'LCOGT   '           / Organization responsible for the data
# SITEID  = 'coj     '           / ID code of the Observatory site
# SITE    = 'LCOGT node at Siding Spring Observatory' / Site of the Observatory
# ENCID   = 'clma    '           / ID code of the Enclosure
# ENCLOSUR= 'Clamshell-02'       / Building containing Telescope
# TELID   = '0m4a    '           / ID code of the Telescope
# TELESCOP= '0m4-03  '           / The Name of the Telescope
# LATITUDE=          -31.2728196 / [deg North] Telescope Latitude
# LONGITUD=          149.0708466 / [deg East] Telescope Longitude
# HEIGHT  =             1130.000 / [m] Altitude of Telescope above sea level
# OBSGEO-X=         -4681305.099 / [m] Cartesian X co-ord of telescope (WGS84)
# OBSGEO-Y=          2804939.432 / [m] Cartesian Y co-ord of telescope (WGS84)
# OBSGEO-Z=         -3292370.526 / [m] Cartesian Z co-ord of telescope (WGS84)
# OBSTYPE = 'EXPOSE  '           / Observation type
# FRAMENUM=                   57 / Running frame number
# MOLTYPE = 'EXPOSE  '           / Molecule type
# MOLNUM  =                   38 / Molecule number
# MOLFRNUM=                    1 / Exposure number within molecule
# FRMTOTAL=                    1 / Total number of exposures within molecule
# ORIGNAME= 'coj0m403-kb97-20191006-0057-e00.fits' / Fname written by ICS
# OBSTELEM= 'N/A     '           / Link to observation telemetry
# TIMESYS = 'UTC     '           / Time system used
# DATE    = '2019-10-06T09:03:32.813549' / [UTC] Date this FITS file was written
# DATE-OBS= '2019-10-06T09:01:34.554' / [UTC] Start date and time of the observati
# DAY-OBS = '20191006'           / [UTC] Date at start of local observing night
# UTSTART = '09:01:34.554'       / [UTC] The start time of the observation
# UTSTOP  = '09:03:04.836'       / [UTC] The finish time of the observation
# MJD-OBS =        58762.3760950 / [UTC days] Start date/time (Modified Julian Dat
# EXPTIME =               90.282 / [s] Actual exposure length
# REQTIME =               90.000 / [s] Requested exposure length
# FILTER1 = 'V       '           / The first filter wheel filter type
# FILTERI1= 'JNSN-VX-124'        / The first filter wheel filter id
# FILTER2 = 'NOTPRESENT'         / The second filter wheel filter type
# FILTERI2= 'NOTPRESENT'         / The second filter wheel filter id
# FILTER3 = 'NOTPRESENT'         / The third filter wheel filter type
# FILTERI3= 'NOTPRESENT'         / The third filter wheel filter id
# FILTER  = 'V       '           / Filter used
# FWID    = 'p4fw50-22'          / Filter Wheel ID
# INSTRUME= 'kb97    '           / Instrument used
# INSSTATE= 'OKAY    '           / The instrument status
# ICSVER  = 'master@0xe2d3343'   / Version number of the ICS software
# CONFMODE= 'default '           / Camera mode configuration
# CONFNAME= 'N/A     '           / The instrument configuration used
# DETECTOR= 'UNKNOWN '           / Detector type
# DETECTID= 'ccdkb97-1'          / Detector serial number
# GAIN    =                  1.0 / [electrons/count] Pixel gain
# RDNOISE =           14.5000000 / [electrons/pixel] Read noise
# DARKCURR=            0.0000000 / [electrons/pixel/s @ 200K] Dark current
# SATURATE=             102400.0 / [ADU] Saturation level
# MAXLIN  =             102400.0 / [ADU] Non-linearity level
# RDSPEED =           30.0000000 / [kpix/s] Readout speed used
# DETSIZE = '[1:0,1:0]'          / [pixel] Detector size
# AMPNAME = 'default '           / Amplifier name
# CCDSEC  = 'UNKNOWN '           / [pixel] Region of CCD read
# CCDSUM  = '1 1     '           / CCD on-chip summing/binning
# BIASSEC = '[3100:3135,1:2048]' / [binned pixel] Section of bias/overscan data
# DATASEC = '[1:3136,1:2112]'    / [binned pixel] Data section
# TRIMSEC = '[18:3071,5:2046]'   / [binned pixel] Section of useful data
# ROI     = 'UNKNOWN '           / [binned pixel] Region of interest or MULTIPLE
# DETSEC  = 'UNKNOWN '           / [binned pixel] Section of useful data
# CCDXPIXE=            0.0000090 / [m] Size of pixels, in X
# CCDYPIXE=            0.0000090 / [m] Size of pixels, in Y
# PIXSCALE=            0.5800000 / [arcsec/pixel] Nominal pixel scale on sky
# CCDSTEMP=          -20.0045808 / [deg C] CCD required temperature
# CCDATEMP=          -20.0045808 / [deg C] CCD actual temperature
# CCDSESIG= 'N/A     '           / [mK] CCD temp control servo error signal
# TELMODE = 'AUTOMATIC'          / Telescope mode
# TAGID   = 'UNSPECIFIED'        / Time Allocation Group ID
# USERID  = 'hwhite  '           / User ID
# PROPID  = 'LCOEPO2019A-001'    / Proposal ID
# GROUPID = 'TestData_Target_A'  / Group ID
# OBSID   = 'UNSPECIFIED'        / Observation ID
# OBSNOTE = 'UNSPECIFIED'        / Observation Note
# SCHEDNAM= 'POND    '           / Name of scheduler in control
# TRACKNUM= '864155  '           / Request DB tracking number
# REQNUM  = '1947705 '           / Request DB request number
# MOLUID  = '55640997'           / Molecule unique ID
# BLKTYPE = 'POND    '           / Group type
# BLKUID  = '28760087'           / Group unique ID
# BLKSDATE= '2019-10-06T09:01:18' / [UTC] Block start date
# BLKEDATE= '2019-10-06T09:06:52' / [UTC] Block end date
# BLKNOMEX=          334.0000000 / [s] Block nominal exec time
# BLKMNPH = 'N/A     '           / [(0-1)] Maximum lunar phase required
# BLKMNDST=           20.0000000 / [deg] Minimum lunar distance required
# BLKSEECO= 'N/A     '           / Minimum seeing required
# BLKTRNCO= 'N/A     '           / Minimum transparency required
# BLKAIRCO= '2.0     '           / Maximum airmass required
# SCHEDSEE=            2.2242377 / [arcsec] Estimated seeing when group scheduled
# SCHEDTRN= 'N/A     '           / [(0-1)] Estimated transparency when group sched
# TRIGGER = 'N/A     '           / External trigger ID
# OBRECIPE= 'N/A     '           / Observing Recipes required/used
# PCRECIPE= 'N/A     '           / Processing Recipes required/used
# PPRECIPE= 'N/A     '           / Post-Processing Recipes required/used
# RA      = '19:56:44.0891'      / [HH:MM:SS.sss] RA where telescope is pointing
# DEC     = '-01:01:20.114'      / [sDD:MM:SS.ss] Dec where telescope is pointing
# RADESYS = 'ICRS    '           / [[FK5,ICRS]] Fundamental coord. system of the o
# LST     = '19:56:47.45'        / [HH:MM:SS.ss] LST at start of current observati
# CAT-RA  = '19:56:44.532'       / [HH:MM:SS.sss] Catalog RA of the object
# CAT-DEC = '-01:01:17.04'       / [sDD:MM:SS.ss] Catalog Dec of the object
# CAT-EPOC=         2000.0000000 / [Year] Catalog epoch of the coordinates
# OFST-RA = '19:56:44.532'       / [HH:MM:SS.sss] Catalog RA plus pointing offsets
# OFST-DEC= '-01:01:17.04'       / [sDD:MM:SS.ss] Catalog Dec plus pointing offset
# TPT-RA  = '20:00:19.373'       / [HH:MM:SS.sss] Telescope demand RA
# TPT-DEC = '-01:28:37.44'       / [sDD:MM:SS.ss] Telescope demand Dec
# OBJECT  = 'Target_A'           / Object name
# SRCTYPE = 'EXTRASOLAR'         / Source type
# PM-RA   =            0.0000000 / [sec/year] Proper motion in RA of the object
# PM-DEC  =            0.0000000 / [arcsec/year] Proper motion in Dec of the objec
# PARALLAX=            0.0000000 / [arcsec] Parallax of the object
# RADVEL  =            0.0000000 / [km/s] Radial velocity of the object
# RATRACK =            0.0000000 / [arcsec/s] Non-sidereal tracking in RA
# DECTRACK=            0.0000000 / [arcsec/s] Non-sidereal tracking in Dec
# TELSTATE= 'OKAY    '           / Current telescope status
# ENGSTATE= 'UNKNOWN '           / Engineering override state
# TCSSTATE= 'OKAY    '           / TCS state
# TCSVER  = '0.4     '           / Version number of the TCS software
# TPNTMODL= '20191006085647'     / Version number of the pointing model
# UT1-UTC =           -0.1529000 / [s] UT1-UTC
# POLARMOX=            0.1934000 / [arcsec] Polar motion X
# POLARMOY=            0.3069000 / [arcsec] Polar motion Y
# EOPSRC  = 'IERS BULL. A 2019/10/03' / Source of the EOP Values
# ROLLERDR=            6.1957571 / [rad] Driven roller encoder angle
# ROLLERND=            6.0579262 / [rad] Non-driven roller encoder angle
# AZDMD   =            0.4819680 / [deg] Azimuth axis demand
# AZIMUTH =            0.4819449 / [deg] Azimuth axis position
# AZSTAT  = 'OKAY    '           / Azimuth axis state
# ALTDMD  =           59.6923125 / [deg] Altitude axis demand
# ALTITUDE=           59.6923651 / [deg] Altitude axis position
# ALTSTAT = 'OKAY    '           / Altitude axis state
# ROTTYPE = 'NONE    '           / Selected image derotator
# ROTMODE = 'FIXED   '           / Rotator mode
# ROTDMD  =            0.0000000 / [deg] Rotator axis demand
# ROTANGLE= 'N/A     '           / [deg] Rotator axis position
# ROTSKYPA=          -90.0000000 / [deg] Rotator position angle
# ROTSTAT = 'OFF     '           / Rotator axis state
# AIRMASS =            1.1579416 / Effective mean airmass
# AMSTART =            1.1579450 / Airmass at start of observation
# AMEND   =            1.1579382 / Airmass at end of observation
# ENC1STAT= 'OPEN    '           / Enclosure shutter 1 state
# ENC2STAT= 'OPEN    '           / Enclosure shutter 2 state
# ENCAZ   =            0.0000000 / [deg] Enclosure azimuth
# ENCWLIGT= 'UNKNOWN '           / Enclosure white lights state
# ENCRLIGT= 'UNKNOWN '           / Enclosure red lights state
# FOLDSTAT= 'ERROR   '           / Fold mirror state
# FOLDPORT= '1       '           / Fold mirror port
# FOLDPOSN= '00.0, N/A'          / [{mm,deg}] Fold mirror position (r, theta)
# M1COVER = 'STOWED  '           / M1 mirror cover state
# M1HRTMN = 'STOWED  '           / M1 Hartmann screen state
# FOCDMD  =            0.0000000 / [mm] Demanded focus position in focal plane
# FOCPOSN =            0.0078555 / [mm] Actual focus position in focal plane
# FOCTELZP=            1.5050000 / [mm] Telescope default focus
# FOCINOFF=            0.0000000 / [mm] Instrument focus offset
# FOCTOFF =            0.0529100 / [mm] Thermal correction value
# FOCZOFF =            0.0092392 / [mm] Zenith compression correction
# FOCAFOFF=           -1.6793912 / [mm] Autofocus offset in focal plane
# FOCOBOFF=            0.0000000 / [mm] Observer focus offset/defocus in focal pla
# FOCFLOFF=           -1.0000000 / [mm] Filter focus offset in focal plane
# FOCSTAT = 'HALTED  '           / Focus state
# M2PITCH =         -403.3240000 / [arcsec] M2 tilt about vertex in pitch directio
# M2ROLL  =         -699.7220000 / [arcsec] M2 tilt about vertex in roll direction
# AUXROLL =            0.0000000 / [arcsec] Auxiliary pointing corrections in roll
# AUXPITCH=            0.0000000 / [arcsec] Auxiliary pointing corrections in pitc
# CTYPE1  = 'RA---TAN'           / Type of WCS Projection
# CTYPE2  = 'DEC--TAN'           / Type of WCS Projection
# CRPIX1  =               1527.5 / [pixel] Coordinate of reference point (axis 1)
# CRPIX2  =               1021.5 / [pixel] Coordinate of reference point (axis 2)
# CRVAL1  =        299.183704424 / [deg] RA at the reference pixel
# CRVAL2  =        -1.0222540205 / [deg] Dec at the reference pixel
# CUNIT1  = 'deg     '           / Units of RA
# CUNIT2  = 'deg     '           / Units of Dec
# CD1_1   =   -1.56822542068E-07 / WCS CD transformation matrix
# CD1_2   =    0.000158933613281 / WCS CD transformation matrix
# CD2_1   =   -0.000158933613281 / WCS CD transformation matrix
# CD2_2   =   -1.56822542068E-07 / WCS CD transformation matrix
# WMSSTATE= 'OKAY    '           / WMS system state
# WMSHUMID=           21.1000000 / [%] Current percentage humidity
# WMSTEMP =           22.5000000 / [deg C] External temperature
# WMSPRES =          889.0000000 / [mbar] Atmospheric pressure
# WINDSPEE=           17.2764000 / [km/h] Windspeed
# WINDDIR =          342.0000000 / [deg E of N] Wind direction
# WMSRAIN = 'CLEAR   '           / Rain alert
# WMSMOIST=         5000.0000000 / [mV] Moisture level
# WMSDEWPT=           -0.8000000 / [deg C] Dewpoint
# WMSCLOUD=          -29.8500000 / [deg C] Boltwood sky temperature
# WMSSKYBR=           18.5133106 / [mag/arcsec^2] Measured sky brightness
# SKYMAG  =           18.5183633 / [mag/arcsec^2] Computed (expected) sky brightne
# TUBETEMP=           22.1499996 / [deg C] Temperature of the telescope tube
# M1TEMP  = 'UNKNOWN '           / [deg C] Primary mirror temperature
# FOCTEMP =           22.1499996 / [deg C] Focus temperature
# ISSTEMP = 'UNKNOWN '           / [deg C] ISS temperature
# REFPRES =          889.0000000 / [mbar] Pressure used in refraction calculation
# REFTEMP =           22.5000000 / [deg C] Temperature used in refraction calculat
# REFHUMID=           21.1000000 / [%] Humidity used in refraction calculation
# AGSTATE = 'IDLE    '           / Autoguider software state
# AGCAM   = 'kb97    '           / Camera used for autoguiding
# AGLCKFRC=                 0.00 / [%] Fraction of time AG locked
# AGMODE  = 'MAYBE   '           / Autoguider mode
# AGRA    = 'UNKNOWN '           / [deg] RA of guide star
# AGDEC   = 'UNKNOWN '           / [deg] Dec of guide star
# AGGMAG  = 'UNKNOWN '           / [mag] Autoguider guide star mag
# AGFWHM  = 'UNKNOWN '           / [arcsec] Autoguider FWHM
# AGNSRC  =                    0 / Number of potential guide stars
# AGDX    =            0.0000000 / [pixel] Autoguider correction in X
# AGDY    =            0.0000000 / [pixel] Autoguider correction in Y
# AGMIRDMD= 'UNKNOWN '           / [mm] Autoguider mirror demand
# AGMIRPOS= '00.0, N/A'          / Autoguider mirror position
# AGMIRST = 'ERROR   '           / Autoguider mirror state
# AGFOCDMD= 'UNKNOWN '           / [mm] Autoguider focus demand
# AGFOCUS = 'UNKNOWN '           / [mm] Autoguider focus position
# AGFOCOFF=            0.0000000 / [mm] Autoguider relative focus offset
# AGFOCST = 'UNKNOWN '           / Autoguider focus state
# AGFILTER= 'V,      '           / Autoguider filter
# AGFILTID= 'JNSN-VX-124,'       / Autoguider filter id
# AGFILST = 'Enabled '           / Autoguider filter state
# MOONSTAT= 'UP      '           / [{UP, DOWN}] Moon position at obs start
# MOONFRAC=            0.5663778 / [(0 - 1)] Lunar Illuminated Fraction
# MOONDIST=           22.5270955 / [deg] Lunar distance from target
# MOONALT =           79.1398997 / [deg] Lunar altitude
# SUNDIST =          107.4522570 / [deg] Solar distance from target
# SUNALT  =          -12.0283806 / [deg] Solar altitude
# EXTNAME = 'SCI     '           / Name of extension
# EXTVER  =                    1 / Instance of the extension
# RWSTART = '09:01:33.154'       / [UTC] Raw start time of the observation
# RWSTOP  = '09:03:04.846'       / [UTC] Raw stop time of the observation
# OFSTART =                 1400 / [ms] Camera start latency adjustment
# OFSTOP  =                  -10 / [ms] Camera stop latency adjustment
# L1IDMASK= 'bpm-kb97-1x1-2019-07-18T232606.fits.fz' / Id. of mask file used
# SATFRAC = 8.75705395794681E-06 / Fraction of Pixels that are Saturated
# L1STATOV=                    1 / Status flag for overscan correction
# OVERSCAN=    1044.571537935748 / Overscan value that was subtracted
# L1STATTR=                    1 / Status flag for overscan trimming
# BIASLVL =    14.63373638547358 / Mean bias level of master bias
# L1IDBIAS= 'coj0m403-kb97-20191006-bias-bin1x1.fits' / ID of bias frame
# L1STATBI=                    1 / Status flag for bias frame correction
# L1IDDARK= 'coj0m403-kb97-20191006-dark-bin1x1.fits' / ID of dark frame
# L1STATDA=                    1 / Status flag for dark frame correction
# L1IDFLAT= 'coj0m403-kb97-20191006-skyflat-bin1x1-V.fits' / ID of flat frame
# L1STATFL=                    1 / Status flag for flat field correction
# L1MEAN  =    730.9682932163915 / [counts] Sigma clipped mean of frame background
# L1MEDIAN=    734.3841552734375 / [counts] Median of frame background
# L1SIGMA =    19.14530317382813 / [counts] Robust std dev of frame background
# L1FWHM  =     1.79303257926012 / [arcsec] Frame FWHM in arcsec
# L1ELLIP =   0.1536912501257366 / Mean image ellipticity (1-B/A)
# L1ELLIPA=    15.75534281672655 / [deg] PA of mean image ellipticity
# WCSERR  =                    0 / Error status of WCS fit. 0 for no error
# PNTOFST =    7.319977067769994 / [arcsec] offset of requested and solved center
# RLEVEL  =                   91 / Reduction level
# PIPEVER = '0.26.8  '           / Pipeline version
# L1PUBDAT= '2019-10-06T09:01:34.554' / [UTC] Date the frame becomes public
# BSCALE  =                  1.0
# BZERO   =                  0.0
# HISTORY Image was compressed by CFITSIO using scaled integer quantization:
# HISTORY   q = 64.000000 / quantized level scaling parameter
# HISTORY 'SUBTRACTIVE_DITHER_1' / Pixel Quantization Algorithm
# ZDITHER0=                 2615 / dithering offset when quantizing floats
# CHECKSUM= 'eAnee9mbeAmbe9mb'   / HDU checksum updated 2019-10-06T09:03:26
# DATASUM = '1268934434'         / data unit checksum updated 2019-10-06T09:03:26
# EXTEND  =                    T

# %% [markdown]
# ### Exercise / Question
#
# Print out the time the image was taken and the location. How does this time relate to your requested set of observations?

# %%
# Print the time and location of observation of this exposure

# %% [markdown]
# ### b. Get the background of the image and subtract it; Calculate the error associated with the background.
#
# Note: The error is calculated by adding the rms error of the background and the background subtracted science image together.

# %%
# Background estimation:
sigma_clip = SigmaClip(sigma=3.) # Sigma clip bright obvious things to avoid biasing the background estimate
bkg_estimator = SExtractorBackground() # Apply the SExtractor algorithm to our estimation
bkg = Background2D(
    sci_data.data, (50, 50),
    filter_size=(3, 3),
    sigma_clip=sigma_clip,
    bkg_estimator=bkg_estimator)

# Now let's subtract the background from the data
sci_bkg = sci_data.data - bkg.background

# Define an error image that will be used when calculating photometry
effective_gain = 1.
error = calc_total_error(sci_bkg, bkg.background_rms, effective_gain)

# %% [markdown]
# ### c. For the target star and each reference star, carry out photometry.
#
# Note: Remember to ensure you are using the _background subtracted_ image. This step should output an error of the photometry measurement.

# %%
target_RA  = 299.18555
target_DEC = -1.0214

# Useful reference stars are ones which are bright, but not saturated, and stars which lie within the field of view. 

#-------------------------------------------------------------------
# TO DO: From the list above, choose 5-8 reference stars.
#-------------------------------------------------------------------
# Construct Python lists for the RA and Dec coordinate values for the stars you've selected from the list displayed in pandas above. 
# The list mag_calibrated_ref should be defined by a Python list of the relevant magnitudes (make sure to check what filter was used to capture this frame!) for your chosen reference stars.
# This subset of stars was selected from the APASS DR20 catalog which can be accessed here: 
# https://www.aavso.org/apass-dr10-download

ref_ra             = [299.235864, 299.164421, 299.233458, 299.07643, 299.206894]
ref_dec            = [-1.208262, -1.098525, -0.955927, -0.94525, -1.126769]
mag_calibrated_ref = [8.634, 10.122, 10.364, 11.194, 11.438]

# Calculate instrumental mags for each of the reference stars
mag_uncalibrated_refs,mag_uncalibrated_refs_err     = do_phot_get_mag(sci_bkg,sci_header,error,ref_ra,ref_dec)

# Do photometry on the variable target
mag_uncalibrated_target,mag_uncalibrated_target_err = do_phot_get_mag(sci_bkg,sci_header,error,target_RA,target_DEC)

print('The error in the calibrated magnitude for the target is: \n',mag_uncalibrated_target_err)
# Out:
# The error in the calibrated magnitude for the target is:
#  [0.0165706059358233]

# %% [markdown]
# ### d. Find the magnitude offset between the reference stars and the catalog magnitudes (i.e. the zeropoint) and calculate the magnitude of the target star, and its error.

# %%
# Calculate the zeropoint
offsets = mag_calibrated_ref - np.array(mag_uncalibrated_refs)

# Print the offset values
print('These are the offsets between m_uncalibrated_ref and m_calibrated_ref: \n',offsets)

# Calculate the zeropoint using a median function
zeropoint     = np.median(offsets)
zeropoint_err = np.std(offsets)
print(f'\nThe zeropoint and zeropoint error is: {zeropoint:.3f}, {zeropoint_err:.2f}')
# Out:
# These are the offsets between m_uncalibrated_ref and m_calibrated_ref:
#  [25.0321419  25.16065613 25.173323   25.13897061 25.13661901]
#
# The zeropoint and zeropoint error is: 25.139, 0.05

# %% [markdown]
# Finally, we will calculate a magntitude (with error) for our target star in this frame!

# %%
# Calculate the calibrated magnitude of the target star and it's error

mag_calibrated_target     = mag_uncalibrated_target[0]+zeropoint
mag_calibrated_target_err = mag_uncalibrated_target_err[0] + zeropoint_err

# %% [markdown]
# ## Exercise / Question

# %%
# Print the magnitude and magnitude error of your target.

# %% [markdown]
# # 6. Create a cutout image around the target star
#
#
# The procedure below allows us to create a little cutout of our target star.
#
# We can first define the relevant function:

# %%
# A function that outputs a small cutout of an image given a big image. 

def make_cutout(data,hdr,ra,dec):

    w = wcs.WCS(hdr)
    xcoord, ycoord = w.all_world2pix(ra,dec,1)
    position = np.transpose((xcoord, ycoord))
    size = u.Quantity([120, 120], u.pixel)
    cutout = Cutout2D(data, position, size, wcs=w, mode='strict')

    cutout_wcs = cutout.wcs
    header = cutout_wcs.to_header()
    hdu = fits.PrimaryHDU(data=cutout.data, header=header)

    return hdu

# %% [markdown]
# Then we can plot it out and save this image as a new file named `cutout.png`.

# %%
# Make tiny cutouts of the variable star in each frame
cutout_hdu = make_cutout(sci_bkg,sci_header,target_RA,target_DEC)

# Plot figures using these cutouts and output images
interval = ZScaleInterval()
vmin = interval.get_limits(cutout_hdu.data)[0]
vmax = interval.get_limits(cutout_hdu.data)[1]

plt.subplot(projection=wcs.WCS(cutout_hdu.header))
plt.imshow(cutout_hdu.data, vmin=vmin, vmax=vmax, origin='lower')
plt.xlabel('R.A.')
plt.ylabel('Declination')

# Save the small cutout as a png, with the file name as the time of observation. 
# This can be used later to make a movie of your source
pngname = 'cutout'
plt.savefig(mypath+pngname+'.png', overwrite=True)

# %% [markdown]
# # Final Exercise
#
# Select some other star (different from your target star and not one you have used as a reference star!) as your target star, and calculate the calibrated magnitude of that star in this exposure.
